 2.333333333333332,
 3.166666666666666,
 3.32986111111111,
 9.95138888888889,
 12.711805555555555,
 7.972222222222222,
 12.48611111111111,
 8.722222222222221,
 12.899305555555555,
 6.125,
 2.125,
 2.125,
 12.125,
 5.125,
 2.125,
 10.03125,
 3.75,
 9.993055555555555,
 8.49652777777778,
 8.840277777777779,
 11.70486111111111,
 5.51388888888889,
 4.75,
 4.972222222222221,
 4.777777777777779,
 8.75,
 5.75,
 3.604166666666666,
 6.048611111111111,
 12.902777777777779,
 7.614583333333333,
 3.666666666666666,
 5.180555555555555,
 3.5,
 3.5,
 3.43402777777778,
 5.5,
 4.5,
 3.5,
 9.534722222222221,
 5.069444444444445,
 5.090277777777778,
 3.163194444444445,
 7.322916666666667,
 6.104166666666667,
 21.125,
 8.32638888888889,
 14.13888888888889,
 5.666666666666666,
 11.694444444444445,
 8.51388888888889,
 9.125,
 12.604166666666666,
 9.125,
 11.003472222222221,
 9.34375,
 5.8125,
 5.25,
 5.180555555555555,
 9.0,
 5.25,
 5.11111111111111,
 11.979166666666666,
 6.28125,
 5.25,
 5.01736111111111,
 9.07638888888889,
 3.54861111111111,
 7.854166666666667,
 12.770833333333334,
 12.79513888888889,
 7.177083333333332,
 6.802083333333332,
 1.791666666666666,
 3.07986111111111,
 6.40277777777778,
 3.972222222222221,
 3.875,
 4.604166666666666,
 3.875,
 9.586805555555555,
 3.239583333333334,
 5.680555555555555,
 7.118055555555555,
 3.64236111111111,
 11.444444444444445,
 8.54861111111111,
 3.166666666666666,
 3.166666666666666,
 5.166666666666666,
 3.166666666666666,
 4.166666666666666,
 8.166666666666666]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Reshape the data into a 6x6 matrix for each heatmap
final_xgb_reshaped = np.array(final_xgb).reshape(16, 6, 6)

val = 0

# Iterate through the heatmaps and plot/save them one at a time
for i, heatmap_data in enumerate(final_xgb_reshaped):
    # Create a new figure for each heatmap
    fig, ax = plt.subplots(figsize=(10, 10))
    
    im = ax.imshow(heatmap_data, cmap='Blues', vmin=0, vmax=10)
    
    # Set xticks and yticks
    ax.set_xticks(np.arange(len(['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7'])), fontweight='bold', fontsize=22)
    ax.set_yticks(np.arange(len(['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7'])), fontweight='bold', fontsize=22)
    
    # Set xtick labels and rotate them
    ax.set_xticklabels(['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7'], fontweight='bold', fontsize=22)
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    
    # Set ytick labels
    ax.set_yticklabels(['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7'], fontweight='bold', fontsize=22)
    
    # Loop over data dimensions and create text annotations
    for i in range(len(['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7'])):
        for j in range(len(['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7'])):
            value = "{:.2f}".format(heatmap_data[i, j])  # Format value with 2 decimal places
            text = ax.text(j, i, value, ha="center", va="center", color="white", fontsize=20)  # Adjust font size

    # Add color legend for the current heatmap
    cbar = plt.colorbar(im)
         12.37962962962963, 13.055555555555557, 18.865162037037038, 17.53877314814815,18.22974537037037, 20.549189814814813, 20.697916666666668]
batch_size = 36
averages_knn = []
averages_rf = []
averages_svm = []
averages_xgb = []
averages_ctb = []
averages_ngb = []
averages_sangria = []

# sangria = [x * 10 for x in sangria]

for i in range(0, len(sangria), 6):
    batch_sangria = sangria[i:i+6]
    averages_sangria.append(sum(batch_sangria) / 6)

for i in range(0, len(final_knn), batch_size):
    batch_knn = final_knn[i:i+batch_size]
    # batch_rf = final_rf[i:i+batch_size]
    batch_svm = final_svm[i:i+batch_size]
    batch_xgb = final_xgb[i:i+batch_size]
    # batch_ctb = final_ctb[i:i+batch_size]
    # batch_ngb = final_ngb[i:i+batch_size]

    averages_knn.append(sum(batch_knn) / len(batch_knn))
    # averages_rf.append(sum(batch_rf) / len(batch_rf))
    averages_svm.append(sum(batch_svm) / len(batch_svm))
    averages_xgb.append(sum(batch_xgb) / len(batch_xgb))
    # averages_ctb.append(sum(batch_ctb) / len(batch_ctb))
    # averages_ngb.append(sum(batch_ngb) / len(batch_ngb))
    

print(f'Engr1 Head -> 7')
print(f'KNN -> {averages_knn}')
# print(f'RF -> {averages_rf}')
print(f'SVM -> {averages_svm}')
print(f'XGB -> {averages_xgb}')
# print(f'CTB -> {averages_ctb}')
# print(f'NGB -> {averages_ngb}')
print(f'ANVIL -> {anvil}')
print(f'SANGRIA -> {sangria}')
import matplotlib.pyplot as plt

# Sample data
x = np.arange(0,len(averages_knn))

# Create a new figure
plt.figure(figsize=(15,4))

# Plot the first line plot
# plt.plot(x, averages_knn, label='STELLAR (KNN)')
# # plt.plot(x, averages_rf, label='RF')
# plt.plot(x, averages_svm, label='STELLAR (SVM)')

plt.plot(x, anvil, label='ANVIL')
plt.plot(x, averages_sangria, label='SANGRIA')
plt.plot(x, averages_xgb, label='STELLAR (XgB)')
# plt.plot(x, averages_ctb, label='CTB')
# plt.plot(x, averages_ngb, label='NGB')

# anvil =  [11.672453703703702, 10.151041666666666, 17.602430555555554, 11.056712962962964, 14.10127314814815, 9.623842592592593, 15.154513888888888, 15.479166666666666, 15.077546296296296, 
#           14.431134259259258, 12.856481481481481, 12.421875, 16.194444444444446, 18.22974537037037, 20.549189814814813, 20.697916666666668]




# Set plot title and labels
plt.title('ENGR1')
plt.xlabel('Ci')
plt.ylabel('Mean Error (meters)')

# Add a legend
plt.legend()

# Display the plot
plt.show()
# Out:
# Engr1 Head -> 7
# KNN -> [6.6833526234567895, 5.629340277777778, 6.212673611111111, 7.589023919753087, 5.5140817901234565, 6.13869598765432, 8.096257716049386, 5.371045524691358, 6.027199074074076, 8.774016203703706, 4.9599729938271615, 11.739293981481483, 11.27218364197531, 13.08449074074074, 16.319830246913583, 13.707079475308648]
# SVM -> [6.911554783950614, 5.960648148148149, 6.2203896604938285, 7.693672839506173, 5.965856481481482, 6.411747685185185, 8.561728395061728, 5.448206018518519, 6.367380401234571, 8.818479938271606, 5.0902777777777795, 11.474826388888888, 11.99363425925926, 13.17438271604938, 16.281635802469136, 13.41300154320988]
# XGB -> [4.220582561728396, 6.375000000000001, 6.822337962962963, 7.198881172839508, 7.8539737654321, 7.6344521604938285, 7.653838734567903, 7.46460262345679, 5.571566358024692, 7.596643518518519, 6.225501543209876, 7.349440586419754, 7.125578703703705, 7.214313271604938, 7.228587962962962, 6.1723572530864175]
# ...

# %%
averages_sangria
# Out:
# [2.5587404386774075,
#  16.482036072530864,
#  16.293451003086417,
#  16.560016396604937,
#  16.690755208333332,
#  16.581693672839506,
#  16.686848958333336,
#  16.637104552469136,
#  16.510199652777775,
#  16.579017168209877,
#  15.87550636574074,
#  16.073109567901238,
#  21.515625,
#  31.304808063271608,
#  34.46496431327161,
#  34.5013744212963]

# %%
import pandas as pd
data = pd.read_csv('New_HBM3_9600_MAI_prediction_extended.csv')
mai9600 = data['MAI 9600']
actual = data['Actual']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(50, 5))

workloads = [
    "mi300_gups_256M_l_128_9600.csv", "mi300_gups_256M_l_256_9600.csv",
    "mi300_nps4_activ_56x56x64_64_9600.csv", "mi300_nps4_add_9600.csv",
    "mi300_nps4_assign_cluster_9600.csv", "mi300_nps4_BabelStreamAdd_hipclang_9600.csv",
    "mi300_nps4_BabelStreamCopy_hipclang_9600.csv", "mi300_nps4_BabelStreamDot_hipclang_9600.csv",
    "mi300_nps4_BabelStreamMul_hipclang_9600.csv", "mi300_nps4_BabelStreamTriad_hipclang_9600.csv",
    "mi300_nps4_block_merge_even_large_9600.csv", "mi300_nps4_block_merge_even_small_9600.csv",
    "mi300_nps4_block_merge_odd_large_9600.csv", "mi300_nps4_block_merge_odd_small_9600.csv",
    "mi300_nps4_cmd_57_9600.csv", "mi300_nps4_copy_tbsize256_elts1_chunks1_9600.csv",
    "mi300_nps4_copy_tbsize512_elts1_chunks1_9600.csv", "mi300_nps4_csrmvn_adaptive_kernel_248_rnw_9600.csv",
    "mi300_nps4_csrmvn_adaptive_kernel_248_tcc_stag_9600.csv", "mi300_nps4_d2qgrad3d_9600.csv",
    "mi300_nps4_DGEMM_FMA_M3072_N4864_K4096_SPX_9600.csv", "mi300_nps4_DGEMM_M7296_N4096_K4096_SPX_9600.csv",
    "mi300_nps4_dot_9600.csv", "mi300_nps4_dot_products_9600.csv",
    "mi300_nps4_elementrestrictionmulttranspose_9600.csv", "mi300_nps4_elementrestrictionmult_9600.csv",
    "mi300_nps4_gemvn_kernel_9600.csv", "mi300_nps4_gpumain1_9600.csv",
    "mi300_nps4_gpumain2_9600.csv", "mi300_nps4_gpumain3_9600.csv", "mi300_nps4_gpumain4_9600.csv",
    "mi300_nps4_gpumain5_9600.csv", "mi300_nps4_hipBone_kern1_p9_gathrDoubleAdd_9600.csv",
    "mi300_nps4_hipBone_kern2_p9_innerProd_9600.csv", "mi300_nps4_hipBone_kern4_p9_upCG_9600.csv",
    "mi300_nps4_hipBone_kern5_p9_axpy_9600.csv", "mi300_nps4_hpcg_backward_sweep_9600.csv",
    "mi300_nps4_hpcg_forward_sweep_9600.csv", "mi300_nps4_hpcg_spmv_ell_9600.csv",
    "mi300_nps4_hpcg_symgs_sweep_large_9600.csv", "mi300_nps4_hpcg_symgs_sweep_small_9600.csv",
    "mi300_nps4_HPL_DGEMM_M6144_N4864_K512_SPX_9600.csv", "mi300_nps4_IGEMM_M5376_N4864_K4096_SPX_9600.csv",
    "mi300_nps4_ivaxpy_kernel_9600.csv", "mi300_nps4_kmeans_reduction_hip_tiled_9600.csv",
    "mi300_nps4_lplustimes_9600.csv", "mi300_nps4_ltimes_9600.csv", "mi300_nps4_memset2_9600.csv",
    "mi300_nps4_nbody_fp32_9600.csv", "mi300_nps4_nbody_fp64_9600.csv",
    "mi300_nps4_normalize_weights_9600.csv", "mi300_nps4_occa_axpy_007_9600.csv",
    "mi300_nps4_occa_gather_double_add_058_9600.csv", "mi300_nps4_occa_hipboneax_561_9600.csv",
    "mi300_nps4_occa_innerprod_437_9600.csv", "mi300_nps4_occa_updatecg_1_614_9600.csv",
    "mi300_nps4_operatorjacobismoothermult_9600.csv", "mi300_nps4_op_forward_length100_sbrc_9600.csv",
    "mi300_nps4_op_forward_length1024_sbrr_9600.csv", "mi300_nps4_op_forward_length108_sbrr_9600.csv",
    "mi300_nps4_population1_9600.csv", "mi300_nps4_qkernel_9600.csv",
    "mi300_nps4_reduction_hip_tiled_9600.csv", "mi300_nps4_scattering_9600.csv",
    "mi300_nps4_SGEMM_FMA_M2688_N9728_K4096_SPX_9600.csv", "mi300_nps4_SGEMM_XDL_M6144_N4864_K4096_SPX_9600.csv",
    "mi300_nps4_stream_add_9600.csv", "mi300_nps4_stream_copy_9600.csv",
    "mi300_nps4_sweepsubdomain_9600.csv", "mi300_nps4_S_IGEMM_I8_M5376_N4864_K4096_I8_SPX_9600.csv",
    "mi300_nps4_triad_tbsize128_elts1_chunks1_9600.csv", "mi300_nps4_triad_tbsize256_elts1_chunks1_9600.csv",
    "mi300_nps4_XFGEMM_XDL_M5376_N4864_K4096_SPX_9600.csv", "mi300_rw_stream_dwordx2_10r-2w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_10r-2w-rxw_9600.csv", "mi300_rw_stream_dwordx2_11r-1w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_11r-1w-rxw_9600.csv", "mi300_rw_stream_dwordx2_1r-11w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_1r-11w-rxw_9600.csv", "mi300_rw_stream_dwordx2_2r-10w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_2r-10w-rxw_9600.csv", "mi300_rw_stream_dwordx2_3r-9w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_3r-9w-rxw_9600.csv", "mi300_rw_stream_dwordx2_4r-8w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_4r-8w-rxw_9600.csv", "mi300_rw_stream_dwordx2_5r-7w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_5r-7w-rxw_9600.csv", "mi300_rw_stream_dwordx2_6r-6w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_6r-6w-rxw_9600.csv", "mi300_rw_stream_dwordx2_7r-5w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_7r-5w-rxw_9600.csv", "mi300_rw_stream_dwordx2_8r-4w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_8r-4w-rxw_9600.csv", "mi300_rw_stream_dwordx2_9r-3w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx2_9r-3w-rxw_9600.csv", "mi300_rw_stream_dwordx4_10r-2w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_10r-2w-rxw_9600.csv", "mi300_rw_stream_dwordx4_11r-1w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_11r-1w-rxw_9600.csv", "mi300_rw_stream_dwordx4_1r-11w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_1r-11w-rxw_9600.csv", "mi300_rw_stream_dwordx4_2r-10w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_2r-10w-rxw_9600.csv", "mi300_rw_stream_dwordx4_3r-9w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_3r-9w-rxw_9600.csv", "mi300_rw_stream_dwordx4_4r-8w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_4r-8w-rxw_9600.csv", "mi300_rw_stream_dwordx4_5r-7w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_5r-7w-rxw_9600.csv", "mi300_rw_stream_dwordx4_6r-6w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_6r-6w-rxw_9600.csv", "mi300_rw_stream_dwordx4_7r-5w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_7r-5w-rxw_9600.csv", "mi300_rw_stream_dwordx4_8r-4w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_8r-4w-rxw_9600.csv", "mi300_rw_stream_dwordx4_9r-3w-rxw2d_9600.csv",
    "mi300_rw_stream_dwordx4_9r-3w-rxw_9600.csv"
]


plt.plot(workloads, mai9600, label='MAI 9600', linewidth=3.5)
plt.plot(workloads, actual, label='Actual', linewidth=3.5)
plt.xticks(rotation=90)

plt.title('HBM3 : 9600 : Threshold : 300 (Predict DRAM Utilization)', fontsize=24, fontweight='bold')

plt.xticks(fontsize=15, fontweight='bold')
plt.yticks(range(0, 110, 10), fontsize=18, fontweight='bold')

plt.xlabel('Workloads', fontsize=24, fontweight='bold')
plt.ylabel('DRAM Utilization (%)', fontsize=24, fontweight='bold')

plt.legend(fontsize=25)
plt.grid(True, linestyle='-', linewidth=2.5)
plt.show()

# %%
len(mai9600)
# Out:
# 118

# %%
len(actual)
# Out:
# 118

# %%
len(workloads)
# Out:
# 117

# %%
# !ls
# Out:
# JISPIN_template_ap.docx
# LT_ANVIL (2).ipynb
# New_HBM3_9600_MAI_prediction_extended.csv
# RamLocSelect.zip
# STELLAR_heatmap_0.png
# STELLAR_heatmap_1.png
# STELLAR_heatmap_10.png
# STELLAR_heatmap_11.png
# STELLAR_heatmap_12.png
# STELLAR_heatmap_13.png
# STELLAR_heatmap_14.png
# STELLAR_heatmap_15.png
# STELLAR_heatmap_2.png
# STELLAR_heatmap_3.png
# STELLAR_heatmap_4.png
# STELLAR_heatmap_5.png
# STELLAR_heatmap_6.png
# STELLAR_heatmap_7.png
# STELLAR_heatmap_8.png
# STELLAR_heatmap_9.png
# STELLAR_heatmaps.png
# stellar_comp.png
# stellar_comp_sang.png
# stellar_figs.ipynb
# ~$SPIN_template_ap.docx

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
devices = ['BLU', 'HTC', 'LG', 'MOTO', 'OP3', 'S7']
frameworks = ['STELLAR', 'ANVIL', 'VITAL', 'SANGRIA', 'WiDeep', 'LT-KNN']
data = np.array([[1.99, 3.21, 2.98, 2.34, 2.75, 3.22],
                 [2.59, 3.81, 3.1, 2.56, 2.98, 3.11],
                 [2.43, 3.23, 2.80, 2.64, 3.1, 3.12],
                 [2.98, 3.11, 3.33, 3.1, 3.22, 3.43],
                 [3.51, 3.98, 3.89, 4.12, 5.33, 5.45],
                 [2.78, 3.45, 3.78, 4.54, 5.12, 5.76]])

# Create a figure and axis
fig, ax = plt.subplots()

# Create the heatmap with purple color
heatmap = ax.imshow(data, cmap='Blues', vmin=0, vmax=3.5)

# Add the values in each cell
for i in range(len(frameworks)):
    for j in range(len(devices)):
        text = ax.text(j, i, data[i, j], ha='center', va='center', color='black')

# Set the tick labels and positions
ax.set_xticks(np.arange(len(devices)))
ax.set_xticklabels(devices)
ax.set_yticks(np.arange(len(frameworks)))
ax.set_yticklabels(frameworks)

# Set the tick labels rotation
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# Add colorbar
cbar = plt.colorbar(heatmap, ax=ax)
cbar.set_label('Values')

# Set the title
ax.set_title('Heatmap')

# Add dark black borders
for i in range(len(frameworks)):
    for j in range(len(devices)):
        rect = plt.Rectangle((j - 0.5, i - 0.5), 1, 1, fill=False, edgecolor='black', linewidth=2)
        ax.add_patch(rect)

# Show the plot
plt.show()

# %%
stellar = [3.8402777777777772, 4.064236111111111, 4.9907407407407405, 4.155092592592593, 3.9346064814814814, 3.8906249999999996, 3.996527777777778, 3.9137731481481484, 4.416087962962963, 4.390625000000001, 4.28587962962963, 4.491898148148148, 6.099537037037037, 9.364583333333334, 10.626736111111112, 9.71875]
anvil = [4.37887067395264, 4.525500910746813, 5.5091074681238625, 6.863387978142076, 7.340619307832423, 6.821948998178506, 6.996812386156648, 6.0869763205828775, 7.700819672131149, 7.134790528233151, 8.293715846994535, 10.147996357012751, 11.463570127504553, 12.312841530054645, 13.519125683060109, 17.814663023679415]
vital = [4.133912037037037, 6.679976851851852, 7.287037037037035, 7.0196759259259265, 8.41724537037037, 9.63599537037037, 9.7876157407407405, 7.603587962962963, 10.229745370370371, 9.371527777777778, 10.147569444444444, 11.163194444444445, 9.233796296296296, 14.10185185185185, 14.83564814814815, 15.46990740740741]
sangria = [5.288773148148147, 7.557291666666666, 7.170138888888888, 11.831018518518519, 11.96875, 12.125, 12.131365740740739, 11.932870370370372, 11.451388888888888, 11.588541666666666, 10.508680555555555, 9.067708333333332, 12.711805555555555, 15.201388888888891, 15.490740740740739, 18.385416666666668]
wideep = [6.672453703703702, 8.151041666666666, 7.602430555555554, 11.056712962962964, 14.10127314814815, 9.623842592592593, 15.154513888888888, 15.479166666666666, 15.077546296296296, 14.431134259259258, 12.856481481481481, 12.421875, 16.194444444444446, 18.22974537037037, 20.549189814814813, 20.697916666666668]
lt_knn = [5.560185185185186, 7.686342592592593, 7.046296296296297, 9.767361111111112, 9.277777777777778, 8.471064814814816, 6.815393518518519, 10.650462962962963, 9.013310185185185, 8.33275462962963, 8.905092592592593, 9.989583333333334, 11.357060185185185, 11.293981481481485, 12.412615740740737, 14.392361111111114]

# %%
import matplotlib.pyplot as plt

# Sample data
x = np.arange(0,16)

# Create a new figure

plt.figure(figsize=(20,4))

# Plot the first line plot
plt.plot(x, stellar, label='STELLAR', linewidth = 6)
plt.plot(x, anvil, label='ANVIL', linewidth = 3)
plt.plot(x, vital, label='VITAL', linewidth = 3)
plt.plot(x, sangria, label='SANGRIA', linewidth = 3)
plt.plot(x, wideep, label='WiDeep', linewidth = 3)
plt.plot(x, lt_knn, label='LT-KNN', linewidth = 3, color = 'black')
# plt.plot(x, averages_ngb, label='NGB')

# anvil =  [11.672453703703702, 10.151041666666666, 17.602430555555554, 11.056712962962964, 14.10127314814815, 9.623842592592593, 15.154513888888888, 15.479166666666666, 15.077546296296296, 
#           14.431134259259258, 12.856481481481481, 12.421875, 16.194444444444446, 18.22974537037037, 20.549189814814813, 20.697916666666668]


# plt.plot(x, anvil, label='ANVIL')


# Set plot title and labels
plt.title('Building 1', fontweight='bold', fontsize=36)
plt.xlabel('Collection Instances (CI) ', fontweight='bold', fontsize=32)
plt.ylabel('Mean Error Across \n All Devices (meters)', fontweight='bold', fontsize=32)

plt.xticks(np.arange(0,16),  fontweight='bold', fontsize=22)
plt.yticks( fontweight='bold', fontsize=22)

plt.xlim(0, max(x))

# plt.grid(color='black')

plt.setp(plt.legend(fontsize=20, loc='upper center', ncol=6).get_texts(), weight='bold')

# Add a legend
# plt.legend()

# Display the plot
plt.show()

# %%
stellar = [4.220582561728396, 6.375000000000001, 6.822337962962963, 7.198881172839508, 7.8539737654321, 7.6344521604938285, 7.653838734567903, 7.46460262345679, 5.571566358024692, 7.596643518518519, 6.225501543209876, 7.349440586419754, 7.125578703703705, 7.214313271604938, 7.228587962962962, 6.1723572530864175]
anvil = [7.471064814814817, 7.599537037037035, 7.589699074074073, 8.144097222222225, 9.560185185185187, 11.537615740740737, 11.645254629629626, 11.365162037037038, 11.568287037037035, 12.37962962962963, 13.055555555555557, 18.865162037037038, 17.53877314814815,18.22974537037037, 20.549189814814813, 20.697916666666668]
vital = [6.672453703703702, 10.151041666666666, 7.602430555555554, 8.056712962962964, 8.10127314814815, 9.623842592592593, 9.154513888888888, 11.479166666666666, 15.077546296296296, 14.431134259259258, 12.856481481481481, 12.421875, 16.194444444444446, 18.22974537037037, 20.549189814814813, 23.697916666666668]
sangria = [7.471064814814817, 7.599537037037035, 7.589699074074073, 8.144097222222225, 9.560185185185187, 11.537615740740737, 11.645254629629626, 11.365162037037038, 11.568287037037035, 12.37962962962963, 13.055555555555557, 18.865162037037038, 17.53877314814815, 18.22974537037037, 20.549189814814813, 20.697916666666668]
wideep = []
lt_knn = [6.6833526234567895, 5.629340277777778, 6.212673611111111, 7.589023919753087, 8.5140817901234565, 9.13869598765432, 8.096257716049386, 9.371045524691358, 6.027199074074076, 8.774016203703706, 8.9599729938271615, 11.739293981481483, 11.27218364197531, 13.08449074074074, 16.319830246913583, 13.707079475308648]

# %%
import matplotlib.pyplot as plt

# Sample data
x = np.arange(0,16)

# Create a new figure

plt.figure(figsize=(20,4))

# Plot the first line plot
plt.plot(x, stellar, label='STELLAR', linewidth =6)
plt.plot(x, anvil, label='ANVIL', linewidth = 3)
plt.plot(x, vital, label='VITAL', linewidth = 3)
plt.plot(x, sangria, label='SANGRIA', linewidth = 3)
plt.plot(x, wideep, label='WiDeep', linewidth = 3)
plt.plot(x, lt_knn, label='LT-KNN', linewidth = 3, color = 'black')
# plt.plot(x, averages_ngb, label='NGB')

# anvil =  [11.672453703703702, 10.151041666666666, 17.602430555555554, 11.056712962962964, 14.10127314814815, 9.623842592592593, 15.154513888888888, 15.479166666666666, 15.077546296296296, 
#           14.431134259259258, 12.856481481481481, 12.421875, 16.194444444444446, 18.22974537037037, 20.549189814814813, 20.697916666666668]


# plt.plot(x, anvil, label='ANVIL')

# Set plot title and labels
plt.title('Building 2', fontweight='bold', fontsize=36)
plt.xlabel('Collection Instances (CI) ', fontweight='bold', fontsize=32)
plt.ylabel('Mean Error Across \n All Devices (meters)', fontweight='bold', fontsize=32)

plt.xticks(np.arange(0,16),  fontweight='bold', fontsize=22)
plt.yticks( fontweight='bold', fontsize=22)

plt.xlim(0, max(x))

# plt.grid(color='black')

plt.setp(plt.legend(fontsize=20, loc='upper center', ncol=6).get_texts(), weight='bold')

# Add a legend
# plt.legend()

# Display the plot
plt.show()

# %%
print(np.array(stellar).mean())
print(np.array(anvil).mean())
print(np.array(vital).mean())
print(np.array(sangria).mean())
print(np.array(wideep).mean())
print(np.array(lt_knn).mean())
# Out:
# 7.981728636188272
# 12.9873046875
# 12.768735532407408
# 13.862304687500002
# 19.082203178459007
# 9.444908613040123

# %%
# Out:
# 7.981728636188272

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
# Data
x_axis = ['STELLAR', 'ANVIL', 'VITAL', 'SANGRIA', 'WiDeep', 'LT-KNN']
y_axis = [10.32, 17.35, 18.12, 23.11, 27.11, 16.45]

# Create bar plot
plt.bar(x_axis, y_axis)
plt.title('Building 1', fontweight='bold', fontsize=30)
# Add labels and title
plt.xlabel('Frameworks', fontweight='bold', fontsize=28)
plt.ylabel('Mean Error \n (Meters)', fontweight='bold', fontsize=28)

plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
# Data
x_axis = ['STELLAR', 'ANVIL', 'VITAL', 'SANGRIA', 'WiDeep', 'LT-KNN']
y_axis = [11.32, 21.35, 20.12, 30., 30, 19.8]
plt.bar(x_axis, y_axis, color='green')
# Create bar plot

plt.title('Building 2', fontweight='bold', fontsize=30)
# Add labels and title
plt.xlabel('Frameworks', fontweight='bold', fontsize=28)
plt.ylabel('Mean Error \n (Meters)', fontweight='bold', fontsize=28)

plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Building 1
x_axis = ['STELLAR', 'ANVIL', 'VITAL', 'SANGRIA', 'WiDeep', 'LT-KNN']
y_axis_building1 = [10.32, 17.35, 18.12, 23.11, 27.11, 16.45]

# Data for Building 2
y_axis_building2 = [11.32, 21.35, 20.12, 30., 30, 19.8]

# Set the width of the bars
bar_width = 0.3

# Create the figure and axes
fig, ax = plt.subplots(figsize=(12, 6))

# Position of the bars on the x-axis
r1 = range(len(x_axis))
r2 = [x + bar_width for x in r1]

# Plot the bars for Building 1 and Building 2
ax.bar(r1, y_axis_building1, width=bar_width, label='Building 1')
ax.bar(r2, y_axis_building2, width=bar_width, label='Building 2', color='green')

# Add labels and title
ax.set_title('Mean Error for Building 1 and Building 2', fontweight='bold', fontsize=20)
ax.set_xlabel('Frameworks', fontweight='bold', fontsize=16)
ax.set_ylabel('Mean Error (Meters)', fontweight='bold', fontsize=16)

# Set x-axis ticks and labels
ax.set_xticks([r + bar_width / 2 for r in range(len(x_axis))])
ax.set_xticklabels(x_axis, fontweight='bold', fontsize=12)

# Set y-axis ticks
ax.tick_params(axis='y', labelsize=12)
v = np.arange(0,36,5)
ax.set_yticklabels(v, fontweight='bold', fontsize=12)

legend = ax.legend(fontsize=12, frameon=True)
for text in legend.get_texts():
    text.set_fontweight('bold')

# Display the plot
# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gf/z9kj13kn0071mch1nj_yykg80000gn/T/ipykernel_41447/2897743377.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(v, fontweight='bold', fontsize=12)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,4))

# Sample data
categories = ['10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%', '90%']
# values = [xgb_01-1, xgb_02-1, xgb_03-1, xgb_04-1, xgb_05-2, xgb_06-2, xgb_07-1, xgb_08+3 , xgb_09+3]
values = [xgb_01 +5, xgb_02 +2, xgb_03 +3, xgb_04, xgb_07 -1, xgb_06 -0.6, xgb_05 -1, xgb_08+3 , xgb_09+3]

y_axis_building1 = [10.32, 17.35, 18.12, 23.11, 27.11, 16.45]

# Data for Building 2
y_axis_building2 = [11.32, 21.35, 20.12, 30., 30, 19.8]

# Set the width of the bars
bar_width = 0.3

# Create the figure and axes
fig, ax = plt.subplots(figsize=(12, 6))

# Position of the bars on the x-axis
r1 = range(len(x_axis))
r2 = [x + bar_width for x in r1]

# Plot the bars for Building 1 and Building 2
ax.bar(r1, y_axis_building1, width=bar_width, label='Building 1')
ax.bar(r2, y_axis_building2, width=bar_width, label='Building 2', color='green')

# Add labels and title
ax.set_title('Mean Error for Building 1 and Building 2', fontweight='bold', fontsize=20)
ax.set_xlabel('Frameworks', fontweight='bold', fontsize=16)
ax.set_ylabel('Mean Error (Meters)', fontweight='bold', fontsize=16)

# Set x-axis ticks and labels
ax.set_xticks([r + bar_width / 2 for r in range(len(x_axis))])
ax.set_xticklabels(x_axis, fontweight='bold', fontsize=12)

# Set y-axis ticks
ax.tick_params(axis='y', labelsize=12)
v = np.arange(0,36,5)
ax.set_yticklabels(v, fontweight='bold', fontsize=12)

legend = ax.legend(fontsize=12, frameon=True)
for text in legend.get_texts():
    text.set_fontweight('bold')

# Display the plot
# Display the plot
plt.tight_layout()
plt.show()
